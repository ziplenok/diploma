# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import numpy as np
from tqdm.notebook import tqdm

# %%
df = pd.read_csv('df_final.csv')

# %%
df
# Out:
#        Unnamed: 0  index      iin                    name_surname Points  \
# 0               0      1  1175243  ХАЙРУЛЛИНА ДИЛЬНАЗ ЕРБОЛАТОВНА    137
# 1               1      2  1174974         САДУОВА КАМИЛА ҒАНИҚЫЗЫ    134
# 2               2      3  1031724    ЕРБОЛАТОВА АКБОТА ТАЛГАТОВНА    127
# 3               3      4  1176230     КАШЕНОВА АЙГЕРИМ КАЙРАТОВНА    125
# 4               4      5  1171682         СЕРІКОВА АДИНА ЕРІКҚЫЗЫ    124
# ...           ...    ...      ...                             ...    ...
# 27663       27663    315  1078939       ҚАРЖАУ АЛТЫН ҒАЛЫМЖАНҚЫЗЫ     97
# 27664       27664    316  1088447                 ЕРДИМҰРАТ АҚНҰР     97
# 27665       27665    317  1043063      АҚАБАЕВА КАРАҚАТ ЖЕҢІСҚЫЗЫ     97
# 27666       27666    318   904262        ЕРКІНБЕК ЕРАСЫЛ АЙДОСҰЛЫ     97
# 27667       27667    319  1015058  ҚОЛҒАНАТ АБДУЛАХАТ МЫРЗАБЕКҰЛЫ     97
#
#       Univer_code               specialization_name   Status  \
# 0              13  B001 - Педагогика и психология       City
# 1             302  B001 - Педагогика и психология       City
# 2              13  B001 - Педагогика и психология       City
# 3              25  B001 - Педагогика и психология       City
# 4             302  B001 - Педагогика и психология       City
# ...           ...                               ...      ...
# 27663          13      B095 - Транспортные услуги    Village
# 27664          32      B095 - Транспортные услуги    Village
# 27665          42      B095 - Транспортные услуги    Village
# 27666          27      B095 - Транспортные услуги    Village
# 27667          19      B095 - Транспортные услуги    Village
#
#        суммабалловсертификата преимущественноеправо  ...  \
# 0                          89                  непс  ...
# 1                          89                  непс  ...
# 2                          89                  непс  ...
# 3                          89                  непс  ...
# 4                          89                  непс  ...
# ...                       ...                   ...  ...
# 27663                      97                   мнс  ...
# 27664                      97                   мнс  ...
# 27665                      97                   мнс  ...
# 27666                      97                   мнс  ...
# 27667                      97                   мнс  ...
#
#       Only_specialization_name  2020-2021_Max 2020-2021_Min 2021-2022_Max  \
# 0      Педагогика и психология          131.0          97.0         138.0
# 1      Педагогика и психология          131.0          97.0         138.0
# 2      Педагогика и психология          131.0          97.0         138.0
# 3      Педагогика и психология          131.0          97.0         138.0
# 4      Педагогика и психология          131.0          97.0         138.0
# ...                        ...            ...           ...           ...
# 27663      Транспортные услуги           96.0          80.0         109.0
# 27664      Транспортные услуги           96.0          80.0         109.0
# 27665      Транспортные услуги           96.0          80.0         109.0
# 27666      Транспортные услуги           96.0          80.0         109.0
# 27667      Транспортные услуги           96.0          80.0         109.0
#
#        2021-2022_Min  difference_Max  difference_Min  profile subject_1  \
# 0               97.0             7.0             0.0           Биология
# 1               97.0             7.0             0.0           Биология
# 2               97.0             7.0             0.0           Биология
# 3               97.0             7.0             0.0           Биология
# 4               97.0             7.0             0.0           Биология
# ...              ...             ...             ...                ...
# 27663          103.0            13.0            23.0         Математика
# 27664          103.0            13.0            23.0         Математика
# 27665          103.0            13.0            23.0         Математика
# 27666          103.0            13.0            23.0         Математика
# 27667          103.0            13.0            23.0         Математика
#
#        profile subject_2  Count_difference_per_year
# 0              География                       70.0
# 1              География                       70.0
# 2              География                       70.0
# 3              География                       70.0
# 4              География                       70.0
# ...                  ...                        ...
# 27663          География                      -52.0
# 27664          География                      -52.0
# 27665          География                      -52.0
# 27666          География                      -52.0
# 27667          География                      -52.0
#
# [27668 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'iin', 'name_surname', 'Points', 'Univer_code',
#        'specialization_name', 'Status', 'суммабалловсертификата',
#        'преимущественноеправо', 'среднийбаллаттестата(диплома)',
#        'суммабалловпрофильныхпредметов(творческихэкзаменов)', 'Code',
#        'Only_specialization_name', '2020-2021_Max', '2020-2021_Min',
#        '2021-2022_Max', '2021-2022_Min', 'difference_Max', 'difference_Min',
#        'profile subject_1', 'profile subject_2', 'Count_difference_per_year'],
#       dtype='object')

# %%
df.drop(columns = ['Unnamed: 0', 'iin','name_surname', 'Code', 'Only_specialization_name'],inplace = True)

# %%
df.columns
# Out:
# Index(['index', 'Points', 'Univer_code', 'specialization_name', 'Status',
#        'суммабалловсертификата', 'преимущественноеправо',
#        'среднийбаллаттестата(диплома)',
#        'суммабалловпрофильныхпредметов(творческихэкзаменов)', '2020-2021_Max',
#        '2020-2021_Min', '2021-2022_Max', '2021-2022_Min', 'difference_Max',
#        'difference_Min', 'profile subject_1', 'profile subject_2',
#        'Count_difference_per_year'],
#       dtype='object')

# %%
type(df['Count_difference_per_year'][0])
# Out:
# numpy.float64

# %%
# Errors
# ДЖУМАХАН АЯУЛЫМ
# БАГИРОВ МЯХЯМАД
# ЗЕЙНЕЛЬГАБДИН МИРАС
# АБДРАХИМОВ НУРСУЛТАН
# ГУСЕЙНОВ МАГОМЕД
# АБАВ -БАКИРОВА

# %%
df['Points'][2460]
# Out:
# 'АГА'

# %%
df['Points'][2460] = '106' #025
df['Univer_code'][2460] = '25'


df['Points'][9667] = '118' #421
df['Univer_code'][9667] = '421'

df['Points'][14043] = '86' #522
df['Univer_code'][14043] = '522'

df['Points'][20456] = '50' #053
df['Univer_code'][20456] = '53'

df['Points'][24461] = '68' #036
df['Univer_code'][24461] = '36'

df['Points'][24306] = '67' #036
df['Univer_code'][24306] = '45'
#67 045
# Out:
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Points'][2460] = '106' #025
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Univer_code'][2460] = '25'
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Points'][9667] = '118' #421
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Univer_code'][9667] = '421'
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Points'][14043] = '86' #522
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Univer_code'][14043] = '522'
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Points'][20456] = '50' #053
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Univer_code'][20456] = '53'
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Points'][24461] = '68' #036
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Univer_code'][24461] = '36'
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Points'][24306] = '67' #036
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\7510844.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Univer_code'][24306] = '45'

# %%
df['Univer_code'].value_counts()
for i in range(len(df)):
    if df['Univer_code'][i].isdigit():
        pass
    else:
        print(df['Univer_code'][i], i)

# %%
df.columns
# Out:
# Index(['index', 'Points', 'Univer_code', 'specialization_name', 'Status',
#        'суммабалловсертификата', 'преимущественноеправо',
#        'среднийбаллаттестата(диплома)',
#        'суммабалловпрофильныхпредметов(творческихэкзаменов)', '2020-2021_Max',
#        '2020-2021_Min', '2021-2022_Max', '2021-2022_Min', 'difference_Max',
#        'difference_Min', 'profile subject_1', 'profile subject_2',
#        'Count_difference_per_year'],
#       dtype='object')

# %%
df.head()
# Out:
#    index Points Univer_code               specialization_name Status  \
# 0      1    137          13  B001 - Педагогика и психология     City
# 1      2    134         302  B001 - Педагогика и психология     City
# 2      3    127          13  B001 - Педагогика и психология     City
# 3      4    125          25  B001 - Педагогика и психология     City
# 4      5    124         302  B001 - Педагогика и психология     City
#
#    суммабалловсертификата преимущественноеправо среднийбаллаттестата(диплома)  \
# 0                      89                  непс                         4,571
# 1                      89                  непс                         4,571
# 2                      89                  непс                         4,571
# 3                      89                  непс                         4,571
# 4                      89                  непс                         4,571
#
#    суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                 46            131.0
# 1                                                 46            131.0
# 2                                                 46            131.0
# 3                                                 46            131.0
# 4                                                 46            131.0
#
#    2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0           97.0          138.0           97.0             7.0
# 1           97.0          138.0           97.0             7.0
# 2           97.0          138.0           97.0             7.0
# 3           97.0          138.0           97.0             7.0
# 4           97.0          138.0           97.0             7.0
#
#    difference_Min profile subject_1 profile subject_2  \
# 0             0.0          Биология         География
# 1             0.0          Биология         География
# 2             0.0          Биология         География
# 3             0.0          Биология         География
# 4             0.0          Биология         География
#
#    Count_difference_per_year
# 0                       70.0
# 1                       70.0
# 2                       70.0
# 3                       70.0
# 4                       70.0

# %%
type(df['2020-2021_Max'][0])
# Out:
# numpy.float64

# %%
df.fillna(0)
#df.replace([np.inf, -np.inf], np.nan, inplace=True)
# replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
df = df.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
#df = df.reset_index()

# %%
for i in range(len(df)):
    df['Points'][i] = int(float(df['Points'][i]))
    df['Univer_code'][i] = int(df['Univer_code'][i])
    df['среднийбаллаттестата(диплома)'][i] = float(df['среднийбаллаттестата(диплома)'][i].replace(',', '.'))
    
    df['2020-2021_Max'][i] = int(float(df['2020-2021_Max'][i]))
    df['2020-2021_Min'][i] = int(float(df['2020-2021_Min'][i]))
    
    df['2021-2022_Max'][i] = int(float(df['2021-2022_Max'][i]))
    df['2021-2022_Min'][i] = int(float(df['2021-2022_Min'][i]))
    
    df['difference_Max'][i] = int(float(df['difference_Max'][i]))
    df['difference_Min'][i] = int(float(df['difference_Min'][i]))
    
    #Count_difference_per_year
    df['Count_difference_per_year'][i] = int(float(df['Count_difference_per_year'][i]))
    #print(i)
# Out:
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Points'][i] = int(float(df['Points'][i]))
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Univer_code'][i] = int(df['Univer_code'][i])
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['среднийбаллаттестата(диплома)'][i] = float(df['среднийбаллаттестата(диплома)'][i].replace(',', '.'))
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['2020-2021_Max'][i] = int(float(df['2020-2021_Max'][i]))
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['2020-2021_Min'][i] = int(float(df['2020-2021_Min'][i]))
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['2021-2022_Max'][i] = int(float(df['2021-2022_Max'][i]))
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['2021-2022_Min'][i] = int(float(df['2021-2022_Min'][i]))
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['difference_Max'][i] = int(float(df['difference_Max'][i]))
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['difference_Min'][i] = int(float(df['difference_Min'][i]))
# C:\Users\fazyl\AppData\Local\Temp\ipykernel_6496\867185896.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Count_difference_per_year'][i] = int(float(df['Count_difference_per_year'][i]))

# %%
file_name = 'df_final_telegram.csv'
df.to_csv(file_name, encoding='utf-8-sig')

# %%
df['Points'].value_counts()
# Out:
# 72     553
# 70     536
# 71     535
# 73     534
# 74     533
#       ...
# 133     50
# 134     49
# 138     41
# 139     37
# 140     10
# Name: Points, Length: 91, dtype: int64

# %%
df
# Out:
#        index Points Univer_code               specialization_name   Status  \
# 0          1    137          13  B001 - Педагогика и психология       City
# 1          2    134         302  B001 - Педагогика и психология       City
# 2          3    127          13  B001 - Педагогика и психология       City
# 3          4    125          25  B001 - Педагогика и психология       City
# 4          5    124         302  B001 - Педагогика и психология       City
# ...      ...    ...         ...                               ...      ...
# 27663    315     97          13      B095 - Транспортные услуги    Village
# 27664    316     97          32      B095 - Транспортные услуги    Village
# 27665    317     97          42      B095 - Транспортные услуги    Village
# 27666    318     97          27      B095 - Транспортные услуги    Village
# 27667    319     97          19      B095 - Транспортные услуги    Village
#
#        суммабалловсертификата преимущественноеправо  \
# 0                          89                  непс
# 1                          89                  непс
# 2                          89                  непс
# 3                          89                  непс
# 4                          89                  непс
# ...                       ...                   ...
# 27663                      97                   мнс
# 27664                      97                   мнс
# 27665                      97                   мнс
# 27666                      97                   мнс
# 27667                      97                   мнс
#
#       среднийбаллаттестата(диплома)  \
# 0                             4.571
# 1                             4.571
# 2                             4.571
# 3                             4.571
# 4                             4.571
# ...                             ...
# 27663                         3.643
# 27664                         3.643
# 27665                         3.643
# 27666                         3.643
# 27667                         3.643
#
#        суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                     46            131.0
# 1                                                     46            131.0
# 2                                                     46            131.0
# 3                                                     46            131.0
# 4                                                     46            131.0
# ...                                                  ...              ...
# 27663                                                 57             96.0
# 27664                                                 57             96.0
# 27665                                                 57             96.0
# 27666                                                 57             96.0
# 27667                                                 57             96.0
#
#        2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0               97.0          138.0           97.0             7.0
# 1               97.0          138.0           97.0             7.0
# 2               97.0          138.0           97.0             7.0
# 3               97.0          138.0           97.0             7.0
# 4               97.0          138.0           97.0             7.0
# ...              ...            ...            ...             ...
# 27663           80.0          109.0          103.0            13.0
# 27664           80.0          109.0          103.0            13.0
# 27665           80.0          109.0          103.0            13.0
# 27666           80.0          109.0          103.0            13.0
# 27667           80.0          109.0          103.0            13.0
#
#        difference_Min profile subject_1 profile subject_2  \
# 0                 0.0          Биология         География
# 1                 0.0          Биология         География
# 2                 0.0          Биология         География
# 3                 0.0          Биология         География
# 4                 0.0          Биология         География
# ...               ...               ...               ...
# 27663            23.0        Математика         География
# 27664            23.0        Математика         География
# 27665            23.0        Математика         География
# 27666            23.0        Математика         География
# 27667            23.0        Математика         География
#
#        Count_difference_per_year
# 0                           70.0
# 1                           70.0
# 2                           70.0
# 3                           70.0
# 4                           70.0
# ...                          ...
# 27663                      -52.0
# 27664                      -52.0
# 27665                      -52.0
# 27666                      -52.0
# 27667                      -52.0
#
# [27668 rows x 18 columns]

# %%
df['profile subject_1'].value_counts()
# Out:
# Математика                 16299
# Биология                    6193
# Химия                       1418
# Физика                      1242
# Творческий экзамен          1039
# Иностранный язык             510
# Всемирная история            485
# География                    462
# Казахский /Русский язык       20
# Name: profile subject_1, dtype: int64

# %%
df['profile subject_2'].value_counts()
# Out:
# Физика                           13965
# География                         5534
# Химия                             3330
# Биология                          1296
# Математика                        1242
# Творческий экзамен                1039
# Всемирная история                  653
# Иностранный язык                   504
# Основы права                        85
# Казахская /Русская литература       20
# Name: profile subject_2, dtype: int64

# %% [markdown]
# # Profile Subjects Label Encoding

# %%
# apply "le.fit_transform"

categ = ['profile subject_1', 'profile subject_2']

# Encode Categorical Columns
le_subj = LabelEncoder()
df_encoded = df[categ].apply(le_subj.fit_transform)
df[categ] = df[categ].apply(le_subj.fit_transform)
# df[categ] = df[categ].apply(le.fit_transform)
                            
print(df_encoded)
print(le_subj.classes_)
# Out:
#        profile subject_1  profile subject_2
# 0                      0                  2
# 1                      0                  2
# 2                      0                  2
# 3                      0                  2
# 4                      0                  2
# ...                  ...                ...
# 27663                  5                  2
# 27664                  5                  2
# 27665                  5                  2
# 27666                  5                  2
# 27667                  5                  2
#
# [27668 rows x 2 columns]
# ['Биология' 'Всемирная история' 'География' 'Иностранный язык'
#  'Казахская /Русская литература' 'Математика' 'Основы права'
#  'Творческий экзамен' 'Физика' 'Химия']

# %%
df.head()
# Out:
#    index Points Univer_code               specialization_name Status  \
# 0      1    137          13  B001 - Педагогика и психология     City
# 1      2    134         302  B001 - Педагогика и психология     City
# 2      3    127          13  B001 - Педагогика и психология     City
# 3      4    125          25  B001 - Педагогика и психология     City
# 4      5    124         302  B001 - Педагогика и психология     City
#
#    суммабалловсертификата преимущественноеправо среднийбаллаттестата(диплома)  \
# 0                      89                  непс                         4.571
# 1                      89                  непс                         4.571
# 2                      89                  непс                         4.571
# 3                      89                  непс                         4.571
# 4                      89                  непс                         4.571
#
#    суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                 46            131.0
# 1                                                 46            131.0
# 2                                                 46            131.0
# 3                                                 46            131.0
# 4                                                 46            131.0
#
#    2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0           97.0          138.0           97.0             7.0
# 1           97.0          138.0           97.0             7.0
# 2           97.0          138.0           97.0             7.0
# 3           97.0          138.0           97.0             7.0
# 4           97.0          138.0           97.0             7.0
#
#    difference_Min  profile subject_1  profile subject_2  \
# 0             0.0                  0                  2
# 1             0.0                  0                  2
# 2             0.0                  0                  2
# 3             0.0                  0                  2
# 4             0.0                  0                  2
#
#    Count_difference_per_year
# 0                       70.0
# 1                       70.0
# 2                       70.0
# 3                       70.0
# 4                       70.0

# %%
df['specialization_name'].value_counts()
# Out:
# B057 - Информационные технологии                                    3885
# B058 - Информационная безопасность                                  2641
# B062 - Электротехника и энергетика                                  2166
# B071 - Горное дело и добыча полезных ископаемых                     1366
# B068 - Производство продуктов питания                               1301
# B063 - Электротехника и автоматизация                               1194
# B053 - Химия                                                        1153
# B054 - Физика                                                       1013
# B059 - Коммуникации и коммуникационные технологии                    973
# B079 - Лесное хозяйство                                              968
# B075 - Кадастр и землеустройство                                     909
# B050 - Биологические и смежные науки                                 811
# B052 - Наука о земле                                                 770
# B064  - Механика и металлообработка                                  762
# B051 - Окружающая среда                                              634
# B083 - Ветеринария                                                   539
# B005 - Подготовка учителей физической культуры                       381
# B076 - Стандартизация, сертификация и метрология (по отраслям)       350
# B090 - Социальная работа                                             350
# B003 - Педагогика и методика начального обучения                     349
# B046 - Финансы, экономика, банковское и страховое дело               348
# B091 - Туризм                                                        319
# B095 - Транспортные услуги                                           319
# B077 - Растениеводство                                               316
# B036 - Переводческое дело                                            275
# B011 - Подготовка учителей информатики                               250
# B013 - Подготовка учителей биологии                                  245
# B018 - Подготовка учителей иностранного языка                        235
# B010 - Подготовка учителей физики                                    229
# B002 - Дошкольное обучение и воспитание                              224
# B020 - Специальная педагогика                                        201
# B092 - Досуг                                                         180
# B183 - Агроинженерия                                                 170
# B042 - Журналистика и репортерское дело                              167
# B012  - Подготовка учителей химии                                    143
# B014 - Подготовка учителей географии                                 143
# B031 - Мода, дизайн                                                  140
# B001 - Педагогика и психология                                       137
# B060 - Химическая инженерия и процессы                               122
# B032 - Философия и этика                                             110
# B078 - Животноводство                                                110
# B015 - Подготовка учителей по гуманитарным предметам                 105
# B029 - Аудиовизуальные средства и медиа производство                  99
# B061 - Материаловедение и технологии                                  86
# B047 - Маркетинг и реклама                                            85
# B049 - Право                                                          85
# B035 - Тюркология и востоковедение                                    80
# B140 - Международные отношения и дипломатия                           75
# B030 - Изобразительное искусство                                      44
# B039 - Культурология                                                  30
# B021 - Исполнительское искусство                                      28
# B048 - Трудовые навыки                                                25
# B043 - Библиотечное дело, обработка информации и архивное дело        20
# B080 - Рыбное хозяйство                                                8
# Name: specialization_name, dtype: int64

# %%
df.fillna(0)
# Out:
#        index  Points  Univer_code               specialization_name   Status  \
# 0          1     137           13  B001 - Педагогика и психология       City
# 1          2     134          302  B001 - Педагогика и психология       City
# 2          3     127           13  B001 - Педагогика и психология       City
# 3          4     125           25  B001 - Педагогика и психология       City
# 4          5     124          302  B001 - Педагогика и психология       City
# ...      ...     ...          ...                               ...      ...
# 27663    315      97           13      B095 - Транспортные услуги    Village
# 27664    316      97           32      B095 - Транспортные услуги    Village
# 27665    317      97           42      B095 - Транспортные услуги    Village
# 27666    318      97           27      B095 - Транспортные услуги    Village
# 27667    319      97           19      B095 - Транспортные услуги    Village
#
#        суммабалловсертификата преимущественноеправо  \
# 0                          89                  непс
# 1                          89                  непс
# 2                          89                  непс
# 3                          89                  непс
# 4                          89                  непс
# ...                       ...                   ...
# 27663                      97                   мнс
# 27664                      97                   мнс
# 27665                      97                   мнс
# 27666                      97                   мнс
# 27667                      97                   мнс
#
#        среднийбаллаттестата(диплома)  \
# 0                              4.571
# 1                              4.571
# 2                              4.571
# 3                              4.571
# 4                              4.571
# ...                              ...
# 27663                          3.643
# 27664                          3.643
# 27665                          3.643
# 27666                          3.643
# 27667                          3.643
#
#        суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                     46            131.0
# 1                                                     46            131.0
# 2                                                     46            131.0
# 3                                                     46            131.0
# 4                                                     46            131.0
# ...                                                  ...              ...
# 27663                                                 57             96.0
# 27664                                                 57             96.0
# 27665                                                 57             96.0
# 27666                                                 57             96.0
# 27667                                                 57             96.0
#
#        2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0               97.0          138.0           97.0             7.0
# 1               97.0          138.0           97.0             7.0
# 2               97.0          138.0           97.0             7.0
# 3               97.0          138.0           97.0             7.0
# 4               97.0          138.0           97.0             7.0
# ...              ...            ...            ...             ...
# 27663           80.0          109.0          103.0            13.0
# 27664           80.0          109.0          103.0            13.0
# 27665           80.0          109.0          103.0            13.0
# 27666           80.0          109.0          103.0            13.0
# 27667           80.0          109.0          103.0            13.0
#
#        difference_Min  profile subject_1  profile subject_2  \
# 0                 0.0                  0                  2
# 1                 0.0                  0                  2
# 2                 0.0                  0                  2
# 3                 0.0                  0                  2
# 4                 0.0                  0                  2
# ...               ...                ...                ...
# 27663            23.0                  5                  2
# 27664            23.0                  5                  2
# 27665            23.0                  5                  2
# 27666            23.0                  5                  2
# 27667            23.0                  5                  2
#
#        Count_difference_per_year
# 0                           70.0
# 1                           70.0
# 2                           70.0
# 3                           70.0
# 4                           70.0
# ...                          ...
# 27663                      -52.0
# 27664                      -52.0
# 27665                      -52.0
# 27666                      -52.0
# 27667                      -52.0
#
# [27668 rows x 18 columns]

# %%
import matplotlib.pyplot as plt
plt.xlabel("Points")
plt.ylabel("specialization_name")
plt.scatter(df[['Points']].values ,df['specialization_name'].values,color = 'green', marker='x')

# %% [markdown]
# # Specialization name Label Encoding

# %%
# Specialization name

categ = ['specialization_name']

# Encode Categorical Columns
le_spec = LabelEncoder()
df_encoded_spec = df[categ].apply(le_spec.fit_transform)
df[categ] = df[categ].apply(le_spec.fit_transform)
# df[categ] = df[categ].apply(le.fit_transform)
                            
print(df_encoded_spec)
print(le_spec.classes_)
# Out:
#        specialization_name
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 27663                   51
# 27664                   51
# 27665                   51
# 27666                   51
# 27667                   51
#
# [27668 rows x 1 columns]
# ['B001 - Педагогика и психология  '
#  'B002 - Дошкольное обучение и воспитание  '
#  'B003 - Педагогика и методика начального обучения  '
#  'B005 - Подготовка учителей физической культуры  '
#  'B010 - Подготовка учителей физики  '
#  'B011 - Подготовка учителей информатики  '
#  'B012  - Подготовка учителей химии  '
#  'B013 - Подготовка учителей биологии  '
#  'B014 - Подготовка учителей географии  '
#  'B015 - Подготовка учителей по гуманитарным предметам  '
#  'B018 - Подготовка учителей иностранного языка  '
#  'B020 - Специальная педагогика  ' 'B021 - Исполнительское искусство  '
#  'B029 - Аудиовизуальные средства и медиа производство  '
#  'B030 - Изобразительное искусство  ' 'B031 - Мода, дизайн  '
#  'B032 - Философия и этика  ' 'B035 - Тюркология и востоковедение  '
#  'B036 - Переводческое дело  ' 'B039 - Культурология  '
#  'B042 - Журналистика и репортерское дело  '
#  'B043 - Библиотечное дело, обработка информации и архивное дело  '
#  'B046 - Финансы, экономика, банковское и страховое дело  '
#  'B047 - Маркетинг и реклама  ' 'B048 - Трудовые навыки  '
#  'B049 - Право  ' 'B050 - Биологические и смежные науки  '
#  'B051 - Окружающая среда  ' 'B052 - Наука о земле  ' 'B053 - Химия  '
#  'B054 - Физика  ' 'B057 - Информационные технологии  '
#  'B058 - Информационная безопасность  '
#  'B059 - Коммуникации и коммуникационные технологии  '
#  'B060 - Химическая инженерия и процессы  '
#  'B061 - Материаловедение и технологии  '
#  'B062 - Электротехника и энергетика  '
#  'B063 - Электротехника и автоматизация  '
#  'B064  - Механика и металлообработка  '
#  'B068 - Производство продуктов питания  '
#  'B071 - Горное дело и добыча полезных ископаемых  '
#  'B075 - Кадастр и землеустройство  '
#  'B076 - Стандартизация, сертификация и метрология (по отраслям)  '
#  'B077 - Растениеводство  ' 'B078 - Животноводство  '
#  'B079 - Лесное хозяйство  ' 'B080 - Рыбное хозяйство  '
#  'B083 - Ветеринария  ' 'B090 - Социальная работа  ' 'B091 - Туризм  '
#  'B092 - Досуг  ' 'B095 - Транспортные услуги  '
#  'B140 - Международные отношения и дипломатия  ' 'B183 - Агроинженерия  ']

# %%
df.head()
# Out:
#    index Points Univer_code  specialization_name Status  \
# 0      1    137          13                    0   City
# 1      2    134         302                    0   City
# 2      3    127          13                    0   City
# 3      4    125          25                    0   City
# 4      5    124         302                    0   City
#
#    суммабалловсертификата преимущественноеправо среднийбаллаттестата(диплома)  \
# 0                      89                  непс                         4.571
# 1                      89                  непс                         4.571
# 2                      89                  непс                         4.571
# 3                      89                  непс                         4.571
# 4                      89                  непс                         4.571
#
#    суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                 46            131.0
# 1                                                 46            131.0
# 2                                                 46            131.0
# 3                                                 46            131.0
# 4                                                 46            131.0
#
#    2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0           97.0          138.0           97.0             7.0
# 1           97.0          138.0           97.0             7.0
# 2           97.0          138.0           97.0             7.0
# 3           97.0          138.0           97.0             7.0
# 4           97.0          138.0           97.0             7.0
#
#    difference_Min  profile subject_1  profile subject_2  \
# 0             0.0                  0                  2
# 1             0.0                  0                  2
# 2             0.0                  0                  2
# 3             0.0                  0                  2
# 4             0.0                  0                  2
#
#    Count_difference_per_year
# 0                       70.0
# 1                       70.0
# 2                       70.0
# 3                       70.0
# 4                       70.0

# %% [markdown]
# # Status Label Encoding

# %%
df['Status'].value_counts()
# Out:
# City       24473
# Village     3195
# Name: Status, dtype: int64

# %%
# Status name

categ = ['Status']

# Encode Categorical Columns
le_status = LabelEncoder()
df_encoded_status = df[categ].apply(le_status.fit_transform)
df[categ] = df[categ].apply(le_status.fit_transform)
# df[categ] = df[categ].apply(le.fit_transform)
                            
print(df_encoded_status)
print(le_status.classes_)
# Out:
#        Status
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 27663       1
# 27664       1
# 27665       1
# 27666       1
# 27667       1
#
# [27668 rows x 1 columns]
# ['City' 'Village']

# %%
df.head()
# Out:
#    index Points Univer_code  specialization_name  Status  \
# 0      1    137          13                    0       0
# 1      2    134         302                    0       0
# 2      3    127          13                    0       0
# 3      4    125          25                    0       0
# 4      5    124         302                    0       0
#
#    суммабалловсертификата преимущественноеправо среднийбаллаттестата(диплома)  \
# 0                      89                  непс                         4.571
# 1                      89                  непс                         4.571
# 2                      89                  непс                         4.571
# 3                      89                  непс                         4.571
# 4                      89                  непс                         4.571
#
#    суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                 46            131.0
# 1                                                 46            131.0
# 2                                                 46            131.0
# 3                                                 46            131.0
# 4                                                 46            131.0
#
#    2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0           97.0          138.0           97.0             7.0
# 1           97.0          138.0           97.0             7.0
# 2           97.0          138.0           97.0             7.0
# 3           97.0          138.0           97.0             7.0
# 4           97.0          138.0           97.0             7.0
#
#    difference_Min  profile subject_1  profile subject_2  \
# 0             0.0                  0                  2
# 1             0.0                  0                  2
# 2             0.0                  0                  2
# 3             0.0                  0                  2
# 4             0.0                  0                  2
#
#    Count_difference_per_year
# 0                       70.0
# 1                       70.0
# 2                       70.0
# 3                       70.0
# 4                       70.0

# %% [markdown]
# # Преимущественное Право Label Encoding

# %%
df['преимущественноеправо'].value_counts()
# Out:
# -           19539
# мнс          5073
# аб           1894
# отличник      635
# непс          527
# Name: преимущественноеправо, dtype: int64

# %%
# преимущественноеправо name

categ = ['преимущественноеправо']

# Encode Categorical Columns
le_preimushestvo = LabelEncoder()
df_encoded_preimushestvo = df[categ].apply(le_preimushestvo.fit_transform)
df[categ] = df[categ].apply(le_preimushestvo.fit_transform)
# df[categ] = df[categ].apply(le.fit_transform)
                            
print(df_encoded_preimushestvo)
print(le_preimushestvo.classes_)
# Out:
#        преимущественноеправо
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3
# ...                      ...
# 27663                      2
# 27664                      2
# 27665                      2
# 27666                      2
# 27667                      2
#
# [27668 rows x 1 columns]
# ['-' 'аб' 'мнс' 'непс' 'отличник']

# %%
df.head()
# Out:
#    index Points Univer_code  specialization_name  Status  \
# 0      1    137          13                    0       0
# 1      2    134         302                    0       0
# 2      3    127          13                    0       0
# 3      4    125          25                    0       0
# 4      5    124         302                    0       0
#
#    суммабалловсертификата  преимущественноеправо  \
# 0                      89                      3
# 1                      89                      3
# 2                      89                      3
# 3                      89                      3
# 4                      89                      3
#
#   среднийбаллаттестата(диплома)  \
# 0                         4.571
# 1                         4.571
# 2                         4.571
# 3                         4.571
# 4                         4.571
#
#    суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                 46            131.0
# 1                                                 46            131.0
# 2                                                 46            131.0
# 3                                                 46            131.0
# 4                                                 46            131.0
#
#    2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0           97.0          138.0           97.0             7.0
# 1           97.0          138.0           97.0             7.0
# 2           97.0          138.0           97.0             7.0
# 3           97.0          138.0           97.0             7.0
# 4           97.0          138.0           97.0             7.0
#
#    difference_Min  profile subject_1  profile subject_2  \
# 0             0.0                  0                  2
# 1             0.0                  0                  2
# 2             0.0                  0                  2
# 3             0.0                  0                  2
# 4             0.0                  0                  2
#
#    Count_difference_per_year
# 0                       70.0
# 1                       70.0
# 2                       70.0
# 3                       70.0
# 4                       70.0

# %%
# df = df.reset_index()

# %%
df.fillna(0)
# Out:
#        index  Points  Univer_code  specialization_name  Status  \
# 0          1     137           13                    0       0
# 1          2     134          302                    0       0
# 2          3     127           13                    0       0
# 3          4     125           25                    0       0
# 4          5     124          302                    0       0
# ...      ...     ...          ...                  ...     ...
# 27663    315      97           13                   51       1
# 27664    316      97           32                   51       1
# 27665    317      97           42                   51       1
# 27666    318      97           27                   51       1
# 27667    319      97           19                   51       1
#
#        суммабалловсертификата  преимущественноеправо  \
# 0                          89                      3
# 1                          89                      3
# 2                          89                      3
# 3                          89                      3
# 4                          89                      3
# ...                       ...                    ...
# 27663                      97                      2
# 27664                      97                      2
# 27665                      97                      2
# 27666                      97                      2
# 27667                      97                      2
#
#        среднийбаллаттестата(диплома)  \
# 0                              4.571
# 1                              4.571
# 2                              4.571
# 3                              4.571
# 4                              4.571
# ...                              ...
# 27663                          3.643
# 27664                          3.643
# 27665                          3.643
# 27666                          3.643
# 27667                          3.643
#
#        суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                     46            131.0
# 1                                                     46            131.0
# 2                                                     46            131.0
# 3                                                     46            131.0
# 4                                                     46            131.0
# ...                                                  ...              ...
# 27663                                                 57             96.0
# 27664                                                 57             96.0
# 27665                                                 57             96.0
# 27666                                                 57             96.0
# 27667                                                 57             96.0
#
#        2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0               97.0          138.0           97.0             7.0
# 1               97.0          138.0           97.0             7.0
# 2               97.0          138.0           97.0             7.0
# 3               97.0          138.0           97.0             7.0
# 4               97.0          138.0           97.0             7.0
# ...              ...            ...            ...             ...
# 27663           80.0          109.0          103.0            13.0
# 27664           80.0          109.0          103.0            13.0
# 27665           80.0          109.0          103.0            13.0
# 27666           80.0          109.0          103.0            13.0
# 27667           80.0          109.0          103.0            13.0
#
#        difference_Min  profile subject_1  profile subject_2  \
# 0                 0.0                  0                  2
# 1                 0.0                  0                  2
# 2                 0.0                  0                  2
# 3                 0.0                  0                  2
# 4                 0.0                  0                  2
# ...               ...                ...                ...
# 27663            23.0                  5                  2
# 27664            23.0                  5                  2
# 27665            23.0                  5                  2
# 27666            23.0                  5                  2
# 27667            23.0                  5                  2
#
#        Count_difference_per_year
# 0                           70.0
# 1                           70.0
# 2                           70.0
# 3                           70.0
# 4                           70.0
# ...                          ...
# 27663                      -52.0
# 27664                      -52.0
# 27665                      -52.0
# 27666                      -52.0
# 27667                      -52.0
#
# [27668 rows x 18 columns]

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# # Training Time

# %%
X_df = df.copy() #df.loc[ : , 'Univer_code' : ] #'суммабалловпрофильныхпредметов(творческихэкзаменов)'

# %%
X_df.head()
# Out:
#    index  Points  Univer_code  specialization_name  Status  \
# 0      1     137           13                    0       0
# 1      2     134          302                    0       0
# 2      3     127           13                    0       0
# 3      4     125           25                    0       0
# 4      5     124          302                    0       0
#
#    суммабалловсертификата  преимущественноеправо  \
# 0                      89                      3
# 1                      89                      3
# 2                      89                      3
# 3                      89                      3
# 4                      89                      3
#
#    среднийбаллаттестата(диплома)  \
# 0                          4.571
# 1                          4.571
# 2                          4.571
# 3                          4.571
# 4                          4.571
#
#    суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                 46            131.0
# 1                                                 46            131.0
# 2                                                 46            131.0
# 3                                                 46            131.0
# 4                                                 46            131.0
#
#    2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0           97.0          138.0           97.0             7.0
# 1           97.0          138.0           97.0             7.0
# 2           97.0          138.0           97.0             7.0
# 3           97.0          138.0           97.0             7.0
# 4           97.0          138.0           97.0             7.0
#
#    difference_Min  profile subject_1  profile subject_2  \
# 0             0.0                  0                  2
# 1             0.0                  0                  2
# 2             0.0                  0                  2
# 3             0.0                  0                  2
# 4             0.0                  0                  2
#
#    Count_difference_per_year
# 0                       70.0
# 1                       70.0
# 2                       70.0
# 3                       70.0
# 4                       70.0

# %%
Y_df = df['specialization_name']
X_df.drop(columns = ['index', 'specialization_name'],inplace = True)

# %%
X_df
# Out:
#        Points  Univer_code  Status  суммабалловсертификата  \
# 0         137           13       0                      89
# 1         134          302       0                      89
# 2         127           13       0                      89
# 3         125           25       0                      89
# 4         124          302       0                      89
# ...       ...          ...     ...                     ...
# 27663      97           13       1                      97
# 27664      97           32       1                      97
# 27665      97           42       1                      97
# 27666      97           27       1                      97
# 27667      97           19       1                      97
#
#        преимущественноеправо  среднийбаллаттестата(диплома)  \
# 0                          3                          4.571
# 1                          3                          4.571
# 2                          3                          4.571
# 3                          3                          4.571
# 4                          3                          4.571
# ...                      ...                            ...
# 27663                      2                          3.643
# 27664                      2                          3.643
# 27665                      2                          3.643
# 27666                      2                          3.643
# 27667                      2                          3.643
#
#        суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                     46            131.0
# 1                                                     46            131.0
# 2                                                     46            131.0
# 3                                                     46            131.0
# 4                                                     46            131.0
# ...                                                  ...              ...
# 27663                                                 57             96.0
# 27664                                                 57             96.0
# 27665                                                 57             96.0
# 27666                                                 57             96.0
# 27667                                                 57             96.0
#
#        2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0               97.0          138.0           97.0             7.0
# 1               97.0          138.0           97.0             7.0
# 2               97.0          138.0           97.0             7.0
# 3               97.0          138.0           97.0             7.0
# 4               97.0          138.0           97.0             7.0
# ...              ...            ...            ...             ...
# 27663           80.0          109.0          103.0            13.0
# 27664           80.0          109.0          103.0            13.0
# 27665           80.0          109.0          103.0            13.0
# 27666           80.0          109.0          103.0            13.0
# 27667           80.0          109.0          103.0            13.0
#
#        difference_Min  profile subject_1  profile subject_2  \
# 0                 0.0                  0                  2
# 1                 0.0                  0                  2
# 2                 0.0                  0                  2
# 3                 0.0                  0                  2
# 4                 0.0                  0                  2
# ...               ...                ...                ...
# 27663            23.0                  5                  2
# 27664            23.0                  5                  2
# 27665            23.0                  5                  2
# 27666            23.0                  5                  2
# 27667            23.0                  5                  2
#
#        Count_difference_per_year
# 0                           70.0
# 1                           70.0
# 2                           70.0
# 3                           70.0
# 4                           70.0
# ...                          ...
# 27663                      -52.0
# 27664                      -52.0
# 27665                      -52.0
# 27666                      -52.0
# 27667                      -52.0
#
# [27668 rows x 16 columns]

# %%
Y_df
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 27663    51
# 27664    51
# 27665    51
# 27666    51
# 27667    51
# Name: specialization_name, Length: 27668, dtype: int32

# %%
x = X_df.values

# %%
x
# Out:
# array([[137.,  13.,   0., ...,   0.,   2.,  70.],
#        [134., 302.,   0., ...,   0.,   2.,  70.],
#        [127.,  13.,   0., ...,   0.,   2.,  70.],
#        ...,
#        [ 97.,  42.,   1., ...,   5.,   2., -52.],
#        [ 97.,  27.,   1., ...,   5.,   2., -52.],
#        [ 97.,  19.,   1., ...,   5.,   2., -52.]])

# %%
df.head()
# Out:
#    index  Points  Univer_code  specialization_name  Status  \
# 0      1     137           13                    0       0
# 1      2     134          302                    0       0
# 2      3     127           13                    0       0
# 3      4     125           25                    0       0
# 4      5     124          302                    0       0
#
#    суммабалловсертификата  преимущественноеправо  \
# 0                      89                      3
# 1                      89                      3
# 2                      89                      3
# 3                      89                      3
# 4                      89                      3
#
#    среднийбаллаттестата(диплома)  \
# 0                          4.571
# 1                          4.571
# 2                          4.571
# 3                          4.571
# 4                          4.571
#
#    суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                 46            131.0
# 1                                                 46            131.0
# 2                                                 46            131.0
# 3                                                 46            131.0
# 4                                                 46            131.0
#
#    2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0           97.0          138.0           97.0             7.0
# 1           97.0          138.0           97.0             7.0
# 2           97.0          138.0           97.0             7.0
# 3           97.0          138.0           97.0             7.0
# 4           97.0          138.0           97.0             7.0
#
#    difference_Min  profile subject_1  profile subject_2  \
# 0             0.0                  0                  2
# 1             0.0                  0                  2
# 2             0.0                  0                  2
# 3             0.0                  0                  2
# 4             0.0                  0                  2
#
#    Count_difference_per_year
# 0                       70.0
# 1                       70.0
# 2                       70.0
# 3                       70.0
# 4                       70.0

# %%
# Y_df = df['Points']
y = Y_df.values

# %%
y
# Out:
# array([ 0,  0,  0, ..., 51, 51, 51])

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.5, random_state = 42) # , random_state = 42


scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
x_train_stat,x_test_stat,y_train_stat,y_test_stat = train_test_split(X_df,Y_df,test_size = 0.2, random_state = 42)

# %%
x_test_stat.describe()
# Out:
#             Points  Univer_code       Status  суммабалловсертификата  \
# count  5534.000000  5534.000000  5534.000000             5534.000000
# mean     86.003433    99.016082     0.109866               72.589989
# std      22.165990   156.119616     0.312751               21.877073
# min      50.000000     2.000000     0.000000               50.000000
# 25%      68.000000    16.000000     0.000000               55.000000
# 50%      83.000000    29.000000     0.000000               69.000000
# 75%     104.000000    57.000000     0.000000               88.000000
# max     140.000000   522.000000     1.000000              124.000000
#
#        преимущественноеправо  среднийбаллаттестата(диплома)  \
# count            5534.000000                    5534.000000
# mean                0.576617                       4.026127
# std                 0.987818                       0.685364
# min                 0.000000                       3.000000
# 25%                 0.000000                       3.500000
# 50%                 0.000000                       4.133000
# 75%                 1.000000                       4.571000
# max                 4.000000                       5.000000
#
#        суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# count                                        5534.000000      5534.000000
# mean                                           37.758222       121.633719
# std                                            20.571618        30.174367
# min                                            14.000000         0.000000
# 25%                                            21.000000       124.000000
# 50%                                            29.000000       133.000000
# 75%                                            48.000000       136.000000
# max                                            90.000000       140.000000
#
#        2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# count    5534.000000    5534.000000    5534.000000     5534.000000
# mean       69.962956     124.968739      78.827611        3.335020
# std        21.660774      29.890727      25.490615        8.547619
# min         0.000000       0.000000       0.000000     -106.000000
# 25%        61.000000     124.000000      64.000000        0.000000
# 50%        66.000000     138.000000      81.000000        3.000000
# 75%        83.000000     140.000000      98.000000        7.000000
# max       120.000000     140.000000     126.000000       41.000000
#
#        difference_Min  profile subject_1  profile subject_2  \
# count     5534.000000        5534.000000        5534.000000
# mean         8.864655           4.023130           6.101735
# std          9.497930           2.405752           2.964813
# min       -104.000000           0.000000           0.000000
# 25%          1.250000           2.000000           2.000000
# 50%          6.000000           5.000000           8.000000
# 75%         15.000000           5.000000           8.000000
# max         40.000000           8.000000           9.000000
#
#        Count_difference_per_year
# count                5534.000000
# mean                  135.234008
# std                   470.873486
# min                  -340.000000
# 25%                   -58.000000
# 50%                   -20.000000
# 75%                   175.000000
# max                  1552.000000

# %%
X_df.describe()
# Out:
#              Points   Univer_code        Status  суммабалловсертификата  \
# count  27668.000000  27668.000000  27668.000000            27668.000000
# mean      85.777649     96.873319      0.115476               72.375669
# std       22.033588    152.733837      0.319602               21.766609
# min       50.000000      2.000000      0.000000               50.000000
# 25%       68.000000     16.000000      0.000000               55.000000
# 50%       82.000000     29.000000      0.000000               69.000000
# 75%      103.000000     57.000000      0.000000               88.000000
# max      140.000000    522.000000      1.000000              124.000000
#
#        преимущественноеправо  среднийбаллаттестата(диплома)  \
# count           27668.000000                   27668.000000
# mean                0.584104                       4.017186
# std                 0.999680                       0.686790
# min                 0.000000                       3.000000
# 25%                 0.000000                       3.429000
# 50%                 0.000000                       4.071000
# 75%                 1.000000                       4.571000
# max                 4.000000                       5.000000
#
#        суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# count                                       27668.000000     27668.000000
# mean                                           37.537155       121.341080
# std                                            20.468508        30.542476
# min                                            14.000000         0.000000
# 25%                                            21.000000       122.000000
# 50%                                            29.000000       133.000000
# 75%                                            48.000000       136.000000
# max                                            90.000000       140.000000
#
#        2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# count   27668.000000   27668.000000   27668.000000    27668.000000
# mean       69.873175     124.753903      78.772553        3.412823
# std        21.701030      30.106364      25.461710        8.201026
# min         0.000000       0.000000       0.000000     -106.000000
# 25%        61.000000     123.000000      64.000000        0.000000
# 50%        66.000000     137.000000      81.000000        3.000000
# 75%        83.000000     140.000000      98.000000        7.000000
# max       120.000000     140.000000     126.000000       41.000000
#
#        difference_Min  profile subject_1  profile subject_2  \
# count    27668.000000       27668.000000       27668.000000
# mean         8.899378           4.004120           6.107995
# std          9.187414           2.405788           2.969279
# min       -104.000000           0.000000           0.000000
# 25%          2.000000           2.000000           2.000000
# 50%          6.000000           5.000000           8.000000
# 75%         15.000000           5.000000           8.000000
# max         40.000000           8.000000           9.000000
#
#        Count_difference_per_year
# count               27668.000000
# mean                  135.218447
# std                   472.296441
# min                  -340.000000
# 25%                   -58.000000
# 50%                   -20.000000
# 75%                   175.000000
# max                  1552.000000

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,y_train)
y_pred = nb.predict(X_test)
print('Accuracy:{:.2f}'.format(accuracy_score(y_test,y_pred)))
# Out:
# Accuracy:1.00

# %%
import time
start_time = time.time()
y_pred = nb.predict(X_test)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.1050105094909668 seconds ---

# %% [markdown]
# # Logistic Regression

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score

# lr = LogisticRegression(solver='liblinear', penalty='l1')
# lr.fit(X_train, y_train)
# pred = lr.predict(X_test)
# print('Accuracy:{:.2f}'.format(accuracy_score(y_test,pred)))

# %%
# import time
# start_time = time.time()
# pred = lr.predict(X_test)
# print("--- %s seconds ---" % (time.time() - start_time))

# %% [markdown]
# # GridSearchCV Logistic Regression

# %%
# import numpy as np
# from sklearn.model_selection import GridSearchCV

# parameters = { 'dual':(False, True), 'C':[0.001, 0.01, 0.1, 1, 10, 100, 1000], 'fit_intercept':(True, False)
# , 'tol':[0.0001, 0.001, 0.01, 0.1]} # это гиперпараметры Logistic Regression 
# lr = LogisticRegression(max_iter=1000, penalty='l2') # это нужно чтобы закинуть внутрь GridSearchCV
# lr.get_params().keys() # гиперпараметры Logistic regression

# clf = GridSearchCV(lr, parameters) # создаем модельку GridSearchCV
# clf.fit(X_train, y_train) # Здесь закидываем данные чтобы оно тренировалось

# %%
# print("model score: %.3f" % clf.score(X_test, y_test)) # показывает точность модельки GridSearchCV}

# %% [markdown]
# # K Nearest Neighbors

# %%
# from sklearn.neighbors import KNeighborsClassifier
# classifier = KNeighborsClassifier(n_neighbors=5)
# classifier.fit(X_train, y_train)

# y_pred = classifier.predict(X_test)

# #print(confusion_matrix(y_test, y_pred))
# #print(classification_report(y_test, y_pred))
# print('Accuracy:{:.2f}'.format(accuracy_score(y_test,y_pred)))

# %%
# import time
# start_time = time.time()
# y_pred = classifier.predict(X_test)
# print("--- %s seconds ---" % (time.time() - start_time))

# %% [markdown]
# # SVM

# %%
# from sklearn import svm
# clf = svm.SVC()
# clf.fit(X_train, y_train)

# y_pred = clf.predict(X_test)
# print(confusion_matrix(y_test, y_pred))
# print(classification_report(y_test, y_pred))
# print('Accuracy:{:.2f}'.format(accuracy_score(y_test,y_pred)))

# %%
# import time
# start_time = time.time()
# y_pred = clf.predict(X_test)
# print("--- %s seconds ---" % (time.time() - start_time))

# %% [markdown]
# # Decision Tree Classifier

# %%
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import KFold

# dtc = DecisionTreeClassifier(criterion='entropy')
# kf = KFold(n_splits=5, shuffle=True)
# dtc.fit(X_train, y_train)

# %%
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# import time

# for criterion in ['gini', 'entropy']:
#     print('Decision Tree -{}'.format(criterion))
#     accuracy = []
#     precision = []
#     recall = []
#     for train_index, test_index in kf.split(x):
#         X_train, X_test = x[train_index], x[test_index]
#         y_train, y_test = y[train_index], y[test_index]
#         dt = DecisionTreeClassifier(criterion=criterion)
#         dt.fit(X_train, y_train)
#         y_pred = dt.predict(X_test)
        
# #         start_time = time.time()
# #         y_pred = dt.predict(X_test)
# #         print("--- %s seconds ---" % (time.time() - start_time))
        
#         accuracy.append(accuracy_score(y_test, y_pred))
#         #precision.append(precision_score(y_test, y_pred))
#         #recall.append(recall_score(y_test, y_pred))
#     start_time = time.time()
#     y_pred = dt.predict(X_test)
#     print("--- %s seconds ---" % (time.time() - start_time))
    
#     print(f'accuracy: {np.mean(accuracy)}')
#     #print(f'precision: {np.mean(precision)}')
#     #print(f'recall: {np.mean(recall)}')
# print()

# %%
list(X_df.columns)
# Out:
# ['Points',
#  'Univer_code',
#  'Status',
#  'суммабалловсертификата',
#  'преимущественноеправо',
#  'среднийбаллаттестата(диплома)',
#  'суммабалловпрофильныхпредметов(творческихэкзаменов)',
#  '2020-2021_Max',
#  '2020-2021_Min',
#  '2021-2022_Max',
#  '2021-2022_Min',
#  'difference_Max',
#  'difference_Min',
#  'profile subject_1',
#  'profile subject_2',
#  'Count_difference_per_year']

# %%
# from sklearn.tree import export_graphviz

# from sklearn.tree import export_graphviz
# import graphviz
# from IPython.display import Image
# from IPython.display import display

# feature_names = ['Points'] # , 'Univer_code'
# X = X_df[feature_names].values
# y = Y_df.values

# dt = DecisionTreeClassifier()
# dt.fit(X, y)

# dot_file = export_graphviz(dt, feature_names=feature_names)
# graph = graphviz.Source(dot_file)
# graph.render(filename='tree', format='png', cleanup=True)
# display(Image(filename='tree.png'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 12>()
#       9 X = X_df[feature_names].values
#      10 y = Y_df.values
# ---> 12 dt = DecisionTreeClassifier()
#      13 dt.fit(X, y)
#      15 dot_file = export_graphviz(dt, feature_names=feature_names)
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %%
# import matplotlib.pyplot as plt
# plt.xlabel("Points")
# plt.ylabel("specialization_name")
# plt.scatter(df[['Points']].values ,df['specialization_name'].values,color = 'green', marker='x')

# %%
df.groupby('Points').count()['specialization_name'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
plt.hist(df['specialization_name'])
# Out:
# (array([1570.,  871.,  512.,  682., 1354., 7455., 7182., 4688., 1941.,
#         1413.]),
#  array([ 0. ,  5.3, 10.6, 15.9, 21.2, 26.5, 31.8, 37.1, 42.4, 47.7, 53. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a simple line plot
df.plot(kind='bar',x='specialization_name',y='Points')
# Out:
# <AxesSubplot:xlabel='specialization_name'>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# gca stands for 'get current axis'
ax = plt.gca()

df.plot(kind='line',x='specialization_name',y='Points',ax=ax)
df.plot(kind='line',x='specialization_name',y='Points', color='red', ax=ax)

plt.show()

# %%
df_test = pd.DataFrame(
    3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "y"]
)

df_test.plot.pie(subplots=True, figsize=(8, 4));

# %%
df_test
# Out:
#           x         y
# a  1.792500  2.188462
# b  2.214242  0.285824
# c  2.376752  0.315937
# d  0.419322  0.406080

# %%
plot = df.plot.pie(y='specialization_name', figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\torch\lib\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\envs\torch\lib\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~\anaconda3\envs\torch\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\envs\torch\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\torch\lib\site-packages\matplotlib\_api\deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File ~\anaconda3\envs\torch\lib\site-packages\matplotlib\backends\backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\envs\torch\lib\site-packages\matplotlib\backends\backend_agg.py:431, in FigureCanvasAgg.draw(self)
#     429 def draw(self):
#     430     # docstring inherited
# --> 431     self.renderer = self.get_renderer(cleared=True)
#     432     # Acquire a lock on the shared font cache.
#     433     with RendererAgg.lock, \
#     434          (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435           else nullcontext()):
#
# File ~\anaconda3\envs\torch\lib\site-packages\matplotlib\backends\backend_agg.py:447, in FigureCanvasAgg.get_renderer(self, cleared)
#     444 reuse_renderer = (hasattr(self, "renderer")
#     445                   and getattr(self, "_lastKey", None) == key)
#     446 if not reuse_renderer:
# --> 447     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448     self._lastKey = key
#     449 elif cleared:
#
# File ~\anaconda3\envs\torch\lib\site-packages\matplotlib\backends\backend_agg.py:93, in RendererAgg.__init__(self, width, height, dpi)
#      91 self.width = width
#      92 self.height = height
# ---> 93 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94 self._filter_renderers = []
#      96 self._update_methods()
#
# ValueError: Image size of 450x579521 pixels is too large. It must be less than 2^16 in each direction.

# %%
df.head()
# Out:
#    index  Points  Univer_code  specialization_name  Status  \
# 0      1     137           13                    0       0
# 1      2     134          302                    0       0
# 2      3     127           13                    0       0
# 3      4     125           25                    0       0
# 4      5     124          302                    0       0
#
#    суммабалловсертификата  преимущественноеправо  \
# 0                      89                      3
# 1                      89                      3
# 2                      89                      3
# 3                      89                      3
# 4                      89                      3
#
#    среднийбаллаттестата(диплома)  \
# 0                          4.571
# 1                          4.571
# 2                          4.571
# 3                          4.571
# 4                          4.571
#
#    суммабалловпрофильныхпредметов(творческихэкзаменов)  2020-2021_Max  \
# 0                                                 46            131.0
# 1                                                 46            131.0
# 2                                                 46            131.0
# 3                                                 46            131.0
# 4                                                 46            131.0
#
#    2020-2021_Min  2021-2022_Max  2021-2022_Min  difference_Max  \
# 0           97.0          138.0           97.0             7.0
# 1           97.0          138.0           97.0             7.0
# 2           97.0          138.0           97.0             7.0
# 3           97.0          138.0           97.0             7.0
# 4           97.0          138.0           97.0             7.0
#
#    difference_Min  profile subject_1  profile subject_2  \
# 0             0.0                  0                  2
# 1             0.0                  0                  2
# 2             0.0                  0                  2
# 3             0.0                  0                  2
# 4             0.0                  0                  2
#
#    Count_difference_per_year
# 0                       70.0
# 1                       70.0
# 2                       70.0
# 3                       70.0
# 4                       70.0

# %%
df['specialization_name']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 27663    51
# 27664    51
# 27665    51
# 27666    51
# 27667    51
# Name: specialization_name, Length: 27668, dtype: int32
